# %%
import numpy as np

# %%
uniform_samples = np.random.rand(1000,2) # array 1000 x 2

# %%
gaussian_samples = np.random.randn(1000,2)

# %%
#numpy.linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0, *, device=None)
N = 100
xs = np.linspace(0, 10, N)
ys = np.e * xs + np.e + (2 * np.random.rand(N) - 1)

# %%
# Select randomly from xs 20 elemenets
batch = 20
idx = np.random.choice(xs, batch, replace= False)
xs_batch = xs[idx]
ys_batch = ys[idx]

# %%
# mix the values from 0 to 9
N = 10
permutation = np.random.permutation(N)

per = np.random.permutation([1, 4, 9, 12, 15])
# ---> array([15,  1,  9,  4, 12]) # random

arr = np.arange(9).reshape((3, 3))
arr1 = np.random.permutation(arr)
# --> array([[6, 7, 8], # random
#           [0, 1, 2],
#           [3, 4, 5]])
